# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
# a
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import json 
import os

import pandas as pd

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in /opt/conda/lib/python3.10/site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /opt/conda/lib/python3.10/site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.8.30)
# Requirement already satisfied: hstspreload in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.11.1)
# Requirement already satisfied: sniffio in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.3.1)
# Requirement already satisfied: chardet==3.* in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /opt/conda/lib/python3.10/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /opt/conda/lib/python3.10/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /opt/conda/lib/python3.10/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /opt/conda/lib/python3.10/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /opt/conda/lib/python3.10/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)

# %%
from googletrans import Translator

# %%
# from nltk.corpus import wordnet

# %%
# nltk.download('wordnet')

# %%
with open('/kaggle/input/nlp-pilot-dataset/pilot_dataset.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
# data

# %%
entries = []
for item in data.values():
    sentence = item['sentence']
    for annotation in item['annotation']:
        entry = {
            'sentence': sentence,
            'target': annotation['target'],
            'snippet': annotation['snippet'],
            'aspect': annotation['aspect'],
            'sentiment': annotation['sentiment'],
            'reasoning': annotation['reasoning']
        }
        entries.append(entry)

# Step 3: Create a DataFrame
df = pd.DataFrame(entries)

# %%
df
# Out:
#                                               sentence               target  \
# 0    ICICI Direct is bullish on Tata Motors has rec...          Tata Motors
# 1    ICICI Direct is bullish on Tata Motors has rec...          Tata Motors
# 2    All three verticals of jewellery, watches, and...            jewellery
# 3    All three verticals of jewellery, watches, and...              watches
# 4    All three verticals of jewellery, watches, and...              eyewear
# ..                                                 ...                  ...
# 427  Motilal Oswal recommended Neutral rating on Ne...         Nestle India
# 428  Investors would look at the outlook for limite...  Avenue Therapeutics
# 429  Investors would look at the outlook for limite...     inhaler products
# 430  Prabhudas Lilladher is bullish on Bajaj Financ...        Bajaj Finance
# 431  Prabhudas Lilladher is bullish on Bajaj Financ...        Bajaj Finance
#
#                                                snippet  \
# 0    ICICI Direct is bullish on Tata Motors has rec...
# 1                               target price of Rs 600
# 2    jewellery reported robust year on year and seq...
# 3    watches reported robust year on year and seque...
# 4    eyewear reported robust year on year and seque...
# ..                                                 ...
# 427  Neutral rating on Nestle India with a target p...
# 428                    decision on Avenue Therapeutics
# 429              update on inhaler products for the US
# 430  Prabhudas Lilladher is bullish on Bajaj Financ...
# 431                            target price of Rs 3815
#
#                             aspect sentiment  \
# 0      Market/Stock Recommendation  positive
# 1        Market/Stock Target Price  positive
# 2     Corporate/Operational Health  positive
# 3     Corporate/Operational Health  positive
# 4     Corporate/Operational Health  positive
# ..                             ...       ...
# 427            Market/Stock Rating   neutral
# 428  Market/Operational Efficiency   neutral
# 429  Market/Operational Efficiency   neutral
# 430    Market/Stock Recommendation  positive
# 431      Market/Stock Target Price  positive
#
#                                              reasoning
# 0    The recommendation to buy indicates a positive...
# 1    A target price of Rs 600 suggests an expected ...
# 2    The robust growth in jewellery indicates stron...
# 3    The robust growth in watches signifies healthy...
# 4    The robust growth in eyewear reflects strong o...
# ..                                                 ...
# 427  The neutral rating suggests that the stock is ...
# 428  The mention of a decision on Avenue Therapeuti...
# 429  An update on inhaler products indicates a focu...
# 430  The recommendation to buy the stock indicates ...
# 431  The target price of Rs 3815 suggests an expect...
#
# [432 rows x 6 columns]

# %%
class BackTranslation:
    def __init__(self, source_language='en', intermediate_language='es'):
        self.source_language = source_language
        self.intermediate_language = intermediate_language
        self.translator = Translator()

    def translate(self, text):
        # Translate from source to intermediate language
        translated = self.translator.translate(text, src=self.source_language, dest=self.intermediate_language)
        # Translate back from intermediate language to source language
        back_translated = self.translator.translate(translated.text, src=self.intermediate_language, dest=self.source_language)
        return back_translated.text

# %%
# Create instances with different intermediate languages: Hindi, Chinese, and Korean
back_translation_hi = BackTranslation(intermediate_language='hi')  # Hindi
back_translation_zh = BackTranslation(intermediate_language='zh-cn')  # Chinese (Simplified)
back_translation_ko = BackTranslation(intermediate_language='ko')  # Korean

# Test the instances
text = "Prabhudas Lilladher is bullish on Mahindra and Mahindra and has recommended a buy rating on the stock."

print("Original:", text)
print("Backtranslation (Hindi):", back_translation_hi.translate(text))
print("Backtranslation (Chinese):", back_translation_zh.translate(text))
print("Backtranslation (Korean):", back_translation_ko.translate(text))
# Out:
# Original: Prabhudas Lilladher is bullish on Mahindra and Mahindra and has recommended a buy rating on the stock.
# Backtranslation (Hindi): Prabhudas Lilader is fast on Mahindra and Mahindra and recommended a purchase rating on stock.
# Backtranslation (Chinese): Prabhudas Lilladher looks at Mahindra and Mahindra, and recommends buying the stock rating.
# Backtranslation (Korean): Prabhudas Lilladher was optimistic at Mahindra and Mahindra and recommended a purchase rating for stocks.

# %%
# Function to generate new rows with translated text
def augment_dataframe(df):
    augmented_data = []

    for _, row in df.iterrows():

        original_sentence = row['sentence']

        # Apply back translation for each intermediate language
        translated_hi = back_translation_hi.translate(original_sentence)
        translated_zh = back_translation_zh.translate(original_sentence)
        translated_ko = back_translation_ko.translate(original_sentence)

        # Create 3 new rows for each intermediate language
        augmented_data.append({
            'sentence': original_sentence,
            'target': row['target'],
            'snippet': row['snippet'],
            'aspect': row['aspect'],
            'sentiment': row['sentiment'],
            'reasoning': row['reasoning'],
            'language': 'original'  # Original
        })
        
        augmented_data.append({
            'sentence': translated_hi,
            'target': row['target'],
            'snippet': row['snippet'],
            'aspect': row['aspect'],
            'sentiment': row['sentiment'],
            'reasoning': row['reasoning'],
            'language': 'hi'  # Hindi
        })
        augmented_data.append({
            'sentence': translated_zh,
            'target': row['target'],
            'snippet': row['snippet'],
            'aspect': row['aspect'],
            'sentiment': row['sentiment'],
            'reasoning': row['reasoning'],
            'language': 'zh-cn'  # Chinese
        })
        augmented_data.append({
            'sentence': translated_ko,
            'target': row['target'],
            'snippet': row['snippet'],
            'aspect': row['aspect'],
            'sentiment': row['sentiment'],
            'reasoning': row['reasoning'],
            'language': 'ko'  # Korean
        })

    # Create a new DataFrame with augmented data
    augmented_df = pd.DataFrame(augmented_data)
    return augmented_df

# %%
# Example: Assuming `df` is your DataFrame
sampled_df = df.sample(frac=0.15, random_state=42)
sampled_df
# Out:
#                                               sentence  \
# 424  Axis Securities is bullish on Britannia Indust...
# 75   Net Sales are expected to decrease by 6.9 perc...
# 180  Prabhudas Lilladher is bullish on Tech Mahindr...
# 30   KR Choksey is bullish on SBI Life Insurance Co...
# 392  ICICI Direct is bullish on Dr Reddy's Laborato...
# ..                                                 ...
# 355  The increase of 32.4 percent in gross revenue ...
# 284  Kotak Institutional Equities too expects the b...
# 79   Motilal Oswal is bullish on Coal India recomme...
# 90   Prabhudas Lilladher is bullish on HDFC Bank ha...
# 367  The RBI has asked HDFC Bank to temporarily hal...
#
#                          target  \
# 424        Britannia Industries
# 75                    Net Sales
# 180               Tech Mahindra
# 30   SBI Life Insurance Company
# 392     Dr Reddy's Laboratories
# ..                          ...
# 355         consumer businesses
# 284                    the bank
# 79                   Coal India
# 90                    HDFC Bank
# 367                   HDFC Bank
#
#                                                snippet  \
# 424                            target price of Rs 5110
# 75   Net Sales are expected to increase by 1.2 perc...
# 180  Prabhudas Lilladher is bullish on Tech Mahindr...
# 30                             target price of Rs 1705
# 392  ICICI Direct is bullish on Dr Reddy's Laborato...
# ..                                                 ...
# 355  continued growth momentum across consumer busi...
# 284  the bank to make higher provisions resulting i...
# 79                              target price of Rs 325
# 90                             target price of Rs 2000
# 367  stop the launch of its digital business-genera...
#
#                            aspect sentiment  \
# 424     Market/Stock Target Price  positive
# 75       Financial/Revenue Growth  positive
# 180   Market/Stock Recommendation  positive
# 30      Market/Stock Target Price  positive
# 392   Market/Stock Recommendation  positive
# ..                            ...       ...
# 355  Corporate/Operational Health  positive
# 284        Corporate/Revenue Base  negative
# 79      Market/Stock Target Price  positive
# 90      Market/Stock Target Price  positive
# 367    Corporate/Product Offering  negative
#
#                                              reasoning
# 424  A target price of Rs 5110 suggests an expected...
# 75   A quarter-on-quarter increase in net sales sug...
# 180  The recommendation to buy indicates a positive...
# 30   The target price of Rs 1705 suggests an expect...
# 392  The 'buy' rating indicates a positive outlook ...
# ..                                                 ...
# 355  The continued growth momentum in consumer busi...
# 284  Higher provisions leading to negligible profit...
# 79   The target price of Rs 325 suggests an anticip...
# 90   A target price of Rs 2000 suggests an expected...
# 367  Stopping the launch of digital business-genera...
#
# [65 rows x 6 columns]

# %%
# Generate the augmented DataFrame
augmented_df = augment_dataframe(sampled_df)

# %%
augmented_df
# Out:
#                                               sentence                target  \
# 0    Axis Securities is bullish on Britannia Indust...  Britannia Industries
# 1    Axis Securities is fast on Britannia Industrie...  Britannia Industries
# 2    AXIS Securities's bullishness of British indus...  Britannia Industries
# 3    The AXIS Securities recommended the purchase r...  Britannia Industries
# 4    Net Sales are expected to decrease by 6.9 perc...             Net Sales
# ..                                                 ...                   ...
# 255  Prabhudas Lilladher was optimistic from HDFC B...             HDFC Bank
# 256  The RBI has asked HDFC Bank to temporarily hal...             HDFC Bank
# 257  The RBI has asked HDFC Bank to temporarily sou...             HDFC Bank
# 258  Indian Reserve Bank has asked HDFC Bank to tem...             HDFC Bank
# 259  The RBI has temporarily suspended the new cred...             HDFC Bank
#
#                                                snippet  \
# 0                              target price of Rs 5110
# 1                              target price of Rs 5110
# 2                              target price of Rs 5110
# 3                              target price of Rs 5110
# 4    Net Sales are expected to increase by 1.2 perc...
# ..                                                 ...
# 255                            target price of Rs 2000
# 256  stop the launch of its digital business-genera...
# 257  stop the launch of its digital business-genera...
# 258  stop the launch of its digital business-genera...
# 259  stop the launch of its digital business-genera...
#
#                          aspect sentiment  \
# 0     Market/Stock Target Price  positive
# 1     Market/Stock Target Price  positive
# 2     Market/Stock Target Price  positive
# 3     Market/Stock Target Price  positive
# 4      Financial/Revenue Growth  positive
# ..                          ...       ...
# 255   Market/Stock Target Price  positive
# 256  Corporate/Product Offering  negative
# 257  Corporate/Product Offering  negative
# 258  Corporate/Product Offering  negative
# 259  Corporate/Product Offering  negative
#
#                                              reasoning  language
# 0    A target price of Rs 5110 suggests an expected...  original
# 1    A target price of Rs 5110 suggests an expected...        hi
# 2    A target price of Rs 5110 suggests an expected...     zh-cn
# 3    A target price of Rs 5110 suggests an expected...        ko
# 4    A quarter-on-quarter increase in net sales sug...  original
# ..                                                 ...       ...
# 255  A target price of Rs 2000 suggests an expected...        ko
# 256  Stopping the launch of digital business-genera...  original
# 257  Stopping the launch of digital business-genera...        hi
# 258  Stopping the launch of digital business-genera...     zh-cn
# 259  Stopping the launch of digital business-genera...        ko
#
# [260 rows x 7 columns]

# %%
augmented_df.to_csv("perturbed.csv")
