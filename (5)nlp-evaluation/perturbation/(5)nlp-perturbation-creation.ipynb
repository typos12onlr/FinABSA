# %%
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load

# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
# a
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import json 
import os

import pandas as pd

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 42.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 2.9 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17395 sha256=1c6789bb8dfaabe25f92dfe0584e3843f5e3a3a26f51a063907b0627b7e42502
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: h11
#     Found existing installation: h11 0.14.0
# ...

# %%
from googletrans import Translator

# %%
# from nltk.corpus import wordnet

# %%
# nltk.download('wordnet')

# %%
data= {
  "584": {
    "sentence": "Prabhudas Lilladher is bullish on Mahindra and Mahindra has recommended buy rating on the stock with a target price of Rs 728 in its research report dated November 10, 2020.",
    "annotation": [
      {
        "target": "Mahindra and Mahindra",
        "snippet": "recommended buy rating on the stock",
        "aspect": "Market/Stock Recommendation",
        "sentiment": "positive",
        "reasoning": "The buy rating indicates a positive outlook on the stock's performance, suggesting expected price appreciation."
      },
      {
        "target": "Mahindra and Mahindra",
        "snippet": "a target price of Rs 728",
        "aspect": "Market/Stock Target Price",
        "sentiment": "positive",
        "reasoning": "The target price of Rs 728 suggests an expected increase in stock value, reflecting a positive sentiment towards future market performance."
      }
    ]
  },
  "80": {
    "sentence": "Motilal Oswal recommended Neutral rating on Bajaj Finance with a target price of Rs 3000 in its research report dated July 21, 2020.",
    "annotation": [
      {
        "target": "Bajaj Finance",
        "snippet": "Motilal Oswal recommended Neutral rating on Bajaj Finance",
        "aspect": "Market/Stock Rating",
        "sentiment": "neutral",
        "reasoning": "A 'Neutral' rating suggests that the stock is expected to perform in line with the broader market, indicating neither particularly positive nor negative sentiment."
      }
    ]
  },
  "1931": {
    "sentence": "Anand Rathi is bullish on ICICI Bank has recommended buy rating on the stock with a target price of Rs 1094 in its research report dated November 30, 2022.",
    "annotation": [
      {
        "target": "ICICI Bank",
        "snippet": "Anand Rathi is bullish on ICICI Bank",
        "aspect": "Market/Stock Recommendation",
        "sentiment": "positive",
        "reasoning": "Anand Rathi's bullish stance and buy recommendation indicates confidence in ICICI Bank's future stock performance."
      },
      {
        "target": "ICICI Bank",
        "snippet": "target price of Rs 1094",
        "aspect": "Market/Stock Target Price",
        "sentiment": "positive",
        "reasoning": "A target price of Rs 1094 implies expected upward movement, reflecting a positive outlook on the stock's future valuation."
      }
    ]
  },
  "1388": {
    "sentence": "Motilal Oswal recommended Neutral rating on HDFC Life Insurance with a target price of Rs 650 in its research report dated April 26, 2022.",
    "annotation": [
      {
        "target": "HDFC Life Insurance",
        "snippet": "Motilal Oswal recommended Neutral rating on HDFC Life Insurance",
        "aspect": "Market/Stock Rating",
        "sentiment": "neutral",
        "reasoning": "The neutral rating indicates a balanced outlook with no anticipated increase or decrease in stock performance."
      }
    ]
  },
  "115": {
    "sentence": "Motilal Oswal is bullish on Hindalco recommended buy rating on the stock with a target price of Rs 198 in its research report dated July 29, 2020.",
    "annotation": [
      {
        "target": "Hindalco",
        "snippet": "Motilal Oswal is bullish on Hindalco recommended buy rating on the stock",
        "aspect": "Market/Stock Recommendation",
        "sentiment": "positive",
        "reasoning": "A bullish outlook and a buy rating indicate positive sentiment towards Hindalco's stock performance."
      },
      {
        "target": "Hindalco",
        "snippet": "target price of Rs 198 in its research report dated July 29, 2020",
        "aspect": "Market/Stock Target Price",
        "sentiment": "positive",
        "reasoning": "The setting of a target price at Rs 198 suggests an expectation of stock appreciation, hence a positive outlook."
      }
    ]
  },
  "2510": {
    "sentence": "Prabhudas Lilladher is bullish on Mahindra and Mahindra has recommended buy rating on the stock with a target price of Rs 1740 in its research report dated November 10, 2023.",
    "annotation": [
      {
        "target": "Prabhudas Lilladher",
        "snippet": "Prabhudas Lilladher is bullish on Mahindra and Mahindra",
        "aspect": "Market/Stock Recommendation",
        "sentiment": "positive",
        "reasoning": "The term 'bullish' indicates a positive outlook and the recommendation to buy the stock suggests confidence in future performance."
      },
      {
        "target": "Mahindra and Mahindra",
        "snippet": "recommended buy rating on the stock with a target price of Rs 1740",
        "aspect": "Market/Stock Recommendation",
        "sentiment": "positive",
        "reasoning": "A buy rating reflects a favorable assessment of the stock, suggesting expected appreciation in value."
      },
      {
        "target": "Mahindra and Mahindra",
        "snippet": "target price of Rs 1740",
        "aspect": "Market/Stock Target Price",
        "sentiment": "positive",
        "reasoning": "A specific target price set above current levels indicates anticipated growth in stock value."
      }
    ]
  },
  "31": {
    "sentence": "Prabhudas Lilladher recommended hold rating on Larsen and Toubro Infotech with a target price of Rs 1598 in its research report dated May 21, 2020.",
    "annotation": [
      {
        "target": "Larsen and Toubro Infotech",
        "snippet": "hold rating on Larsen and Toubro Infotech with a target price of Rs 1598",
        "aspect": "Market/Stock Rating",
        "sentiment": "neutral",
        "reasoning": "The 'hold' rating indicates a neutral stance where the stock is expected to perform in line with the market. The target price signifies a moderate expected return."
      }
    ]
  },
  "1922": {
    "sentence": "Motilal Oswal is bullish on Axis Bank recommended buy rating on the stock with a target price of Rs 1050 in its research report dated November 25, 2022.",
    "annotation": [
      {
        "target": "Axis Bank",
        "snippet": "Motilal Oswal is bullish on Axis Bank recommended buy rating on the stock",
        "aspect": "Market/Stock Recommendation",
        "sentiment": "positive",
        "reasoning": "The phrase 'bullish' and 'recommended buy rating' indicate a positive outlook on the stock, suggesting growth or investment potential."
      },
      {
        "target": "Axis Bank",
        "snippet": "target price of Rs 1050",
        "aspect": "Market/Stock Target Price",
        "sentiment": "positive",
        "reasoning": "Setting a target price of Rs 1050 suggests an expectation of future price appreciation, which reflects a positive sentiment towards the stock's performance."
      }
    ]
  },
  "850": {
    "sentence": "This is in addition to the first dividend of Rs 6 per share declared by the board on October 29, 2020 and paid to the eligible shareholders on November 26, Shriram Transport said in a regulatory filing.",
    "annotation": [
      {
        "target": "Shriram Transport",
        "snippet": "first dividend of Rs 6 per share declared by the board on October 29, 2020 and paid to the eligible shareholders on November 26",
        "aspect": "Financial/Revenue Growth",
        "sentiment": "positive",
        "reasoning": "The declaration and payment of a dividend indicates financial health and is typically associated with revenue growth or strong earnings performance."
      }
    ]
  },
  "905": {
    "sentence": "Net Sales are expected to increase by 78.3 percent Y-o-Y (up 9.5 percent Q-o-Q) to Rs 23,198.4 crore, according to Prabhudas Lilladher.",
    "annotation": [
      {
        "target": "Net Sales",
        "snippet": "Net Sales are expected to increase by 78.3 percent Y-o-Y (up 9.5 percent Q-o-Q) to Rs 23,198.4 crore",
        "aspect": "Financial/Revenue Growth",
        "sentiment": "positive",
        "reasoning": "The expected increase in Net Sales by a significant percentage both year-over-year and quarter-over-quarter indicates strong revenue growth potential."
      }
    ]
  }
}

# %%
entries = []
for item in data.values():
    sentence = item['sentence']
    for annotation in item['annotation']:
        entry = {
            'sentence': sentence,
            'target': annotation['target'],
            'snippet': annotation['snippet'],
            'aspect': annotation['aspect'],
            'sentiment': annotation['sentiment'],
            'reasoning': annotation['reasoning']
        }
        entries.append(entry)

# Step 3: Create a DataFrame
df = pd.DataFrame(entries)

# %%
df
# Out:
#                                              sentence  \
# 0   Prabhudas Lilladher is bullish on Mahindra and...
# 1   Prabhudas Lilladher is bullish on Mahindra and...
# 2   Motilal Oswal recommended Neutral rating on Ba...
# 3   Anand Rathi is bullish on ICICI Bank has recom...
# 4   Anand Rathi is bullish on ICICI Bank has recom...
# 5   Motilal Oswal recommended Neutral rating on HD...
# 6   Motilal Oswal is bullish on Hindalco recommend...
# 7   Motilal Oswal is bullish on Hindalco recommend...
# 8   Prabhudas Lilladher is bullish on Mahindra and...
# 9   Prabhudas Lilladher is bullish on Mahindra and...
# 10  Prabhudas Lilladher is bullish on Mahindra and...
# 11  Prabhudas Lilladher recommended hold rating on...
# 12  Motilal Oswal is bullish on Axis Bank recommen...
# 13  Motilal Oswal is bullish on Axis Bank recommen...
# 14  This is in addition to the first dividend of R...
# 15  Net Sales are expected to increase by 78.3 per...
#
#                         target  \
# ...

# %%
class BackTranslation:
    def __init__(self, source_language='en', intermediate_language='es'):
        self.source_language = source_language
        self.intermediate_language = intermediate_language
        self.translator = Translator()

    def translate(self, text):
        # Translate from source to intermediate language
        translated = self.translator.translate(text, src=self.source_language, dest=self.intermediate_language)
        # Translate back from intermediate language to source language
        back_translated = self.translator.translate(translated.text, src=self.intermediate_language, dest=self.source_language)
        return back_translated.text

# %%
# Create instances with different intermediate languages: Hindi, Chinese, and Korean
back_translation_hi = BackTranslation(intermediate_language='hi')  # Hindi
back_translation_zh = BackTranslation(intermediate_language='zh-cn')  # Chinese (Simplified)
back_translation_ko = BackTranslation(intermediate_language='ko')  # Korean

# Test the instances
text = "Prabhudas Lilladher is bullish on Mahindra and Mahindra and has recommended a buy rating on the stock."

print("Original:", text)
print("Backtranslation (Hindi):", back_translation_hi.translate(text))
print("Backtranslation (Chinese):", back_translation_zh.translate(text))
print("Backtranslation (Korean):", back_translation_ko.translate(text))
# Out:
# Original: Prabhudas Lilladher is bullish on Mahindra and Mahindra and has recommended a buy rating on the stock.
# Backtranslation (Hindi): Prabhudas Lilader is fast on Mahindra and Mahindra and recommended a purchase rating on stock.
# Backtranslation (Chinese): Prabhudas Lilladher looks at Mahindra and Mahindra, and recommends buying the stock rating.
# Backtranslation (Korean): Prabhudas Lilladher was optimistic at Mahindra and Mahindra and recommended a purchase rating for stocks.

# %%
# Function to generate new rows with translated text
def augment_dataframe(df):
    augmented_data = []

    for _, row in df.iterrows():
        original_sentence = row['sentence']

        # Apply back translation for each intermediate language
        translated_hi = back_translation_hi.translate(original_sentence)
        translated_zh = back_translation_zh.translate(original_sentence)
        translated_ko = back_translation_ko.translate(original_sentence)

        # Create 3 new rows for each intermediate language
        augmented_data.append({
            'sentence': original_sentence,
            'target': row['target'],
            'snippet': row['snippet'],
            'aspect': row['aspect'],
            'sentiment': row['sentiment'],
            'reasoning': row['reasoning'],
            'language': 'original'  # Original
        })
        
        augmented_data.append({
            'sentence': translated_hi,
            'target': row['target'],
            'snippet': row['snippet'],
            'aspect': row['aspect'],
            'sentiment': row['sentiment'],
            'reasoning': row['reasoning'],
            'language': 'hi'  # Hindi
        })
        augmented_data.append({
            'sentence': translated_zh,
            'target': row['target'],
            'snippet': row['snippet'],
            'aspect': row['aspect'],
            'sentiment': row['sentiment'],
            'reasoning': row['reasoning'],
            'language': 'zh-cn'  # Chinese
        })
        augmented_data.append({
            'sentence': translated_ko,
            'target': row['target'],
            'snippet': row['snippet'],
            'aspect': row['aspect'],
            'sentiment': row['sentiment'],
            'reasoning': row['reasoning'],
            'language': 'ko'  # Korean
        })

    # Create a new DataFrame with augmented data
    augmented_df = pd.DataFrame(augmented_data)
    return augmented_df

# %%
# Generate the augmented DataFrame
augmented_df = augment_dataframe(df)

# %%
augmented_df
# Out:
#                                              sentence                 target  \
# 0   Prabhudas Lilladher is bullish on Mahindra and...  Mahindra and Mahindra
# 1   Prabhudas Lilader is a boom on Mahindra and Ma...  Mahindra and Mahindra
# 2   Prabhudas Lilladher is up to Mahindra. Mahindr...  Mahindra and Mahindra
# 3   Prabhudas Lilladher is optimistic about Mahind...  Mahindra and Mahindra
# 4   Prabhudas Lilladher is bullish on Mahindra and...  Mahindra and Mahindra
# ..                                                ...                    ...
# 59  This was added to the first dividend of RS 6 p...      Shriram Transport
# 60  Net Sales are expected to increase by 78.3 per...              Net Sales
# 61  According to Prabhudas Lilader, 78.3 percent i...              Net Sales
# 62  According to Prabhudas Lilladher, net sales ar...              Net Sales
# 63  According to Prabhudas Lilladher, net sales ar...              Net Sales
#
# ...

# %%
augmented_df.to_csv("perturbed.csv")
